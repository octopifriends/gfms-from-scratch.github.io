# %% [markdown]
# NOTES
#
# Step 1
# - eurosat gives knowledge to go acess the data, not actual data
# - repo already organized into test, train, calidate
# -
#
# Step 2
# - each image has a label, labels note embedded in the image
# - grab random images til one of every label
# - need to do visualization normalization, trained on normalized data Pirthve
# - numbers 0 to 4000 need to remap from 0 to 1 ?
#
# Step 3
#  - grab same bands , normalize band statistics over the dataset not the image level
#  - YOU want to use approaches to use (Normalize band statistics over the dataset!)
#  - Build transofmmms -- object past to the model gives the model the abilirt to do transformations, need to be functions
#  - transformed datasets not have ability to do band selection and image thing
#  - transofrm as go unless using them all every time. Transofrms is second copy of the image can be heavy memory
#
#
# Step 4
# - how we are optimizing them to load in
# - ways to parallelize them
#
# Step 5
# - factory is a algorthimc way of generating objects
# - encoder decoder favroty way of making models,
# - CHECK OUT TASK IN DOCUMENTATION
# - MIGHT change based on task for the build model
# - move model onto the GPU
# - lightning a cool new way to do this! but for now this
# - freeze backbone or not -- frozen becomes much less parameters only decoder
# - model on device -- can train model on normal cpu but will take forever, so need matrice multiplications to happen in parallel, can do that with graphics cards!
# - turn graphics card into general langauge computer
# -  graphics cards that run cuda!!! is running that language want to be navidai cuda
#
# Part 3 Zero-shot evaluation
# - take model and run inference on model images
# - wont work cause not giving labels and wasnt yet trained to distinguish between classes
# - no fine tuning or context just gave sealake
#
# Part 4
# - give small set of images all happen to be the same class level 1. Will create a set of output that have some pattern that locates them in hyperdimensional space
# - NOT decoder if fewshot just in model hyperdimensional space
# - work well in classes look similar, work worse in
# - save encoding dimensions and give it to whichever one is closest. Nearest neighbor things
# - pull 5 random images from each class pass through model and save the average of where they were as the cluster centroids
# - NORMALLY do better at 70% the few shot, not as bad
# - just passed one image through this test so didnt actually learn a lot in this example, would want to alter this code to use more images
#
# Step 6A
# - decoder head training with a few examples
# - still few shot but only a little traing on the decoder
#
#
# NEED NEW THINGS
# - LOSS FUNCTION - how far away we are from what we want
# - OPTIMIZER method for updating parameters within the model
# - CAN have different optimizer for different tasks
# - learning rate, should not move very far because dont want to take big steps (trade off how fast learning rate it
#
# validation loop same but not any updates
#
#
# def train_model( tells you how many epochs you want to do loop the loop!
